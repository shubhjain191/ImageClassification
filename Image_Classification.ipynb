# %%
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.datasets import cifar10
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.utils import to_categorical
from sklearn.metrics import classification_report, confusion_matrix
import seaborn as sns

# %%
print("TensorFlow version:", tf.__version__)
print("GPU Available: ", len(tf.config.list_physical_devices('GPU')) > 0)
# Out:
# TensorFlow version: 2.18.0
# GPU Available:  False

# %%
print("\n1. Loading CIFAR-10 dataset...")
(X_train, y_train), (X_test, y_test) = cifar10.load_data()

# Normalize pixel values between 0 and 1
X_train = X_train.astype('float32') / 255.0
X_test = X_test.astype('float32') / 255.0

# Convert class vectors to binary class matrices (one-hot encoding)
num_classes = 10
y_train = to_categorical(y_train, num_classes)
y_test = to_categorical(y_test, num_classes)

print("Training data shape:", X_train.shape)
print("Training labels shape:", y_train.shape)
print("Test data shape:", X_test.shape)
print("Test labels shape:", y_test.shape)

# Display sample images from the dataset
class_names = ['airplane', 'automobile', 'bird', 'cat', 'deer',
               'dog', 'frog', 'horse', 'ship', 'truck']

plt.figure(figsize=(10, 10))
for i in range(25):
    plt.subplot(5, 5, i+1)
    plt.xticks([])
    plt.yticks([])
    plt.grid(False)
    plt.imshow(X_train[i])
    # The CIFAR labels are arrays, that's why we need the extra index
    plt.title(class_names[y_train[i].argmax()])
plt.tight_layout()
plt.show()
# Out:
# 1. Loading CIFAR-10 dataset...
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170498071/170498071 ━━━━━━━━━━━━━━━━━━━━ 3s 0us/step
# Training data shape: (50000, 32, 32, 3)
# Training labels shape: (50000, 10)
# Test data shape: (10000, 32, 32, 3)
# Test labels shape: (10000, 10)

# %%
print("\n2. Creating CNN model...")
model = keras.Sequential([
    # First convolutional layer
    layers.Conv2D(32, (3, 3), padding='same', activation='relu', input_shape=(32, 32, 3)),
    layers.BatchNormalization(),
    layers.Conv2D(32, (3, 3), padding='same', activation='relu'),
    layers.BatchNormalization(),
    layers.MaxPooling2D(pool_size=(2, 2)),
    layers.Dropout(0.25),

    # Second convolutional layer
    layers.Conv2D(64, (3, 3), padding='same', activation='relu'),
    layers.BatchNormalization(),
    layers.Conv2D(64, (3, 3), padding='same', activation='relu'),
    layers.BatchNormalization(),
    layers.MaxPooling2D(pool_size=(2, 2)),
    layers.Dropout(0.25),

    # Third convolutional layer
    layers.Conv2D(128, (3, 3), padding='same', activation='relu'),
    layers.BatchNormalization(),
    layers.Conv2D(128, (3, 3), padding='same', activation='relu'),
    layers.BatchNormalization(),
    layers.MaxPooling2D(pool_size=(2, 2)),
    layers.Dropout(0.25),

    # Flatten and fully connected layers
    layers.Flatten(),
    layers.Dense(512, activation='relu'),
    layers.BatchNormalization(),
    layers.Dropout(0.5),
    layers.Dense(num_classes, activation='softmax')
])

# Display model summary
model.summary()
# Out:
# 2. Creating CNN model...
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                      │ (None, 32, 32, 32)          │             896 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization                  │ (None, 32, 32, 32)          │             128 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_1 (Conv2D)                    │ (None, 32, 32, 32)          │           9,248 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_1                │ (None, 32, 32, 32)          │             128 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d (MaxPooling2D)         │ (None, 16, 16, 32)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout (Dropout)                    │ (None, 16, 16, 32)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_2 (Conv2D)                    │ (None, 16, 16, 64)          │          18,496 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_2                │ (None, 16, 16, 64)          │             256 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_3 (Conv2D)                    │ (None, 16, 16, 64)          │          36,928 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_3                │ (None, 16, 16, 64)          │             256 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_1 (MaxPooling2D)       │ (None, 8, 8, 64)            │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_1 (Dropout)                  │ (None, 8, 8, 64)            │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_4 (Conv2D)                    │ (None, 8, 8, 128)           │          73,856 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_4                │ (None, 8, 8, 128)           │             512 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_5 (Conv2D)                    │ (None, 8, 8, 128)           │         147,584 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_5                │ (None, 8, 8, 128)           │             512 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_2 (MaxPooling2D)       │ (None, 4, 4, 128)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_2 (Dropout)                  │ (None, 4, 4, 128)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ flatten (Flatten)                    │ (None, 2048)                │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ (None, 512)                 │       1,049,088 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_6                │ (None, 512)                 │           2,048 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_3 (Dropout)                  │ (None, 512)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 10)                  │           5,130 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 1,345,066 (5.13 MB)
#  Trainable params: 1,343,146 (5.12 MB)
#  Non-trainable params: 1,920 (7.50 KB)

# %%
# 3. Compile the model
print("\n3. Compiling model...")
model.compile(
    optimizer=keras.optimizers.Adam(learning_rate=0.001),
    loss='categorical_crossentropy',
    metrics=['accuracy']
)
# Out:
# 3. Compiling model...

# %%
# 4. Data augmentation to prevent overfitting
print("\n4. Setting up data augmentation...")
datagen = ImageDataGenerator(
    rotation_range=15,
    width_shift_range=0.1,
    height_shift_range=0.1,
    horizontal_flip=True,
    zoom_range=0.1
)
datagen.fit(X_train)
# Out:
# 4. Setting up data augmentation...

# %%
# 5. Train the model with callbacks
print("\n5. Training the model...")
# Callbacks for early stopping and model checkpointing
callbacks = [
    keras.callbacks.EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True),
    keras.callbacks.ReduceLROnPlateau(monitor='val_loss', factor=0.2, patience=5, min_lr=1e-6)
]

# Train the model
batch_size = 64
epochs = 50

history = model.fit(
    datagen.flow(X_train, y_train, batch_size=batch_size),
    steps_per_epoch=len(X_train) // batch_size,
    epochs=epochs,
    validation_data=(X_test, y_test),
    callbacks=callbacks,
    verbose=1
)
# Out:
# 5. Training the model...
# Epoch 1/50
# /usr/local/lib/python3.11/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 490s 619ms/step - accuracy: 0.3501 - loss: 2.0937 - val_accuracy: 0.4756 - val_loss: 1.6292 - learning_rate: 0.0010
# Epoch 2/50
#   1/781 ━━━━━━━━━━━━━━━━━━━━ 10:44 826ms/step - accuracy: 0.5000 - loss: 1.3594
# /usr/local/lib/python3.11/dist-packages/keras/src/trainers/epoch_iterator.py:107: UserWarning: Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches. You may need to use the `.repeat()` function when building your dataset.
#   self._interrupted_warning()
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 21s 26ms/step - accuracy: 0.5000 - loss: 1.3594 - val_accuracy: 0.4830 - val_loss: 1.5909 - learning_rate: 0.0010
# Epoch 3/50
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 556s 639ms/step - accuracy: 0.5549 - loss: 1.2435 - val_accuracy: 0.6491 - val_loss: 1.0307 - learning_rate: 0.0010
# Epoch 4/50
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 21s 26ms/step - accuracy: 0.6875 - loss: 1.0275 - val_accuracy: 0.6406 - val_loss: 1.0537 - learning_rate: 0.0010
# Epoch 5/50
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 526s 620ms/step - accuracy: 0.6307 - loss: 1.0431 - val_accuracy: 0.6223 - val_loss: 1.1805 - learning_rate: 0.0010
# Epoch 6/50
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 41s 53ms/step - accuracy: 0.6875 - loss: 0.9029 - val_accuracy: 0.6168 - val_loss: 1.1958 - learning_rate: 0.0010
# Epoch 7/50
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 511s 608ms/step - accuracy: 0.6743 - loss: 0.9305 - val_accuracy: 0.6624 - val_loss: 1.0327 - learning_rate: 0.0010
# Epoch 8/50
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 22s 27ms/step - accuracy: 0.7031 - loss: 0.9821 - val_accuracy: 0.6541 - val_loss: 1.0566 - learning_rate: 0.0010
# Epoch 9/50
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 481s 609ms/step - accuracy: 0.7184 - loss: 0.7988 - val_accuracy: 0.7455 - val_loss: 0.7444 - learning_rate: 2.0000e-04
# Epoch 10/50
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 41s 53ms/step - accuracy: 0.6719 - loss: 0.8915 - val_accuracy: 0.7463 - val_loss: 0.7458 - learning_rate: 2.0000e-04
# Epoch 11/50
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 520s 608ms/step - accuracy: 0.7407 - loss: 0.7417 - val_accuracy: 0.7550 - val_loss: 0.7240 - learning_rate: 2.0000e-04
# Epoch 12/50
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 41s 53ms/step - accuracy: 0.7188 - loss: 0.8747 - val_accuracy: 0.7531 - val_loss: 0.7276 - learning_rate: 2.0000e-04
# Epoch 13/50
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 543s 638ms/step - accuracy: 0.7559 - loss: 0.7038 - val_accuracy: 0.7499 - val_loss: 0.7352 - learning_rate: 2.0000e-04
# Epoch 14/50
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 42s 53ms/step - accuracy: 0.7500 - loss: 0.6867 - val_accuracy: 0.7507 - val_loss: 0.7385 - learning_rate: 2.0000e-04
# Epoch 15/50
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 495s 633ms/step - accuracy: 0.7607 - loss: 0.6873 - val_accuracy: 0.7678 - val_loss: 0.6740 - learning_rate: 2.0000e-04
# Epoch 16/50
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 41s 53ms/step - accuracy: 0.8281 - loss: 0.6039 - val_accuracy: 0.7664 - val_loss: 0.6774 - learning_rate: 2.0000e-04
# Epoch 17/50
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 496s 635ms/step - accuracy: 0.7670 - loss: 0.6648 - val_accuracy: 0.7809 - val_loss: 0.6591 - learning_rate: 2.0000e-04
# Epoch 18/50
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 21s 26ms/step - accuracy: 0.7656 - loss: 0.7290 - val_accuracy: 0.7807 - val_loss: 0.6612 - learning_rate: 2.0000e-04
# Epoch 19/50
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 495s 634ms/step - accuracy: 0.7767 - loss: 0.6475 - val_accuracy: 0.7711 - val_loss: 0.6987 - learning_rate: 2.0000e-04
# Epoch 20/50
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 42s 53ms/step - accuracy: 0.7344 - loss: 0.9300 - val_accuracy: 0.7726 - val_loss: 0.6914 - learning_rate: 2.0000e-04
# Epoch 21/50
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 495s 634ms/step - accuracy: 0.7857 - loss: 0.6240 - val_accuracy: 0.7735 - val_loss: 0.6810 - learning_rate: 2.0000e-04
# Epoch 22/50
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 21s 26ms/step - accuracy: 0.6875 - loss: 0.9161 - val_accuracy: 0.7738 - val_loss: 0.6771 - learning_rate: 2.0000e-04
# Epoch 23/50
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 521s 607ms/step - accuracy: 0.7871 - loss: 0.6057 - val_accuracy: 0.7951 - val_loss: 0.6098 - learning_rate: 4.0000e-05
# Epoch 24/50
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 41s 53ms/step - accuracy: 0.8125 - loss: 0.5411 - val_accuracy: 0.7954 - val_loss: 0.6096 - learning_rate: 4.0000e-05
# Epoch 25/50
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 476s 609ms/step - accuracy: 0.7973 - loss: 0.5844 - val_accuracy: 0.7994 - val_loss: 0.5941 - learning_rate: 4.0000e-05
# Epoch 26/50
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 20s 25ms/step - accuracy: 0.7031 - loss: 0.8062 - val_accuracy: 0.7998 - val_loss: 0.5948 - learning_rate: 4.0000e-05
# Epoch 27/50
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 494s 633ms/step - accuracy: 0.7974 - loss: 0.5844 - val_accuracy: 0.8058 - val_loss: 0.5784 - learning_rate: 4.0000e-05
# Epoch 28/50
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 21s 26ms/step - accuracy: 0.7969 - loss: 0.6696 - val_accuracy: 0.8058 - val_loss: 0.5784 - learning_rate: 4.0000e-05
# Epoch 29/50
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 540s 632ms/step - accuracy: 0.8009 - loss: 0.5744 - val_accuracy: 0.8128 - val_loss: 0.5584 - learning_rate: 4.0000e-05
# Epoch 30/50
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 21s 26ms/step - accuracy: 0.7344 - loss: 0.6680 - val_accuracy: 0.8131 - val_loss: 0.5579 - learning_rate: 4.0000e-05
# Epoch 31/50
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 521s 606ms/step - accuracy: 0.8015 - loss: 0.5768 - val_accuracy: 0.8005 - val_loss: 0.5917 - learning_rate: 4.0000e-05
# Epoch 32/50
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 41s 53ms/step - accuracy: 0.7188 - loss: 0.6888 - val_accuracy: 0.7997 - val_loss: 0.5922 - learning_rate: 4.0000e-05
# Epoch 33/50
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 522s 608ms/step - accuracy: 0.7988 - loss: 0.5701 - val_accuracy: 0.8014 - val_loss: 0.5925 - learning_rate: 4.0000e-05
# Epoch 34/50
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 21s 26ms/step - accuracy: 0.8906 - loss: 0.3451 - val_accuracy: 0.8012 - val_loss: 0.5936 - learning_rate: 4.0000e-05
# Epoch 35/50
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 497s 630ms/step - accuracy: 0.8031 - loss: 0.5642 - val_accuracy: 0.8139 - val_loss: 0.5565 - learning_rate: 4.0000e-05
# Epoch 36/50
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 21s 26ms/step - accuracy: 0.8125 - loss: 0.5916 - val_accuracy: 0.8138 - val_loss: 0.5574 - learning_rate: 4.0000e-05
# Epoch 37/50
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 543s 633ms/step - accuracy: 0.8045 - loss: 0.5626 - val_accuracy: 0.8156 - val_loss: 0.5497 - learning_rate: 4.0000e-05
# Epoch 38/50
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 42s 53ms/step - accuracy: 0.8594 - loss: 0.4725 - val_accuracy: 0.8157 - val_loss: 0.5500 - learning_rate: 4.0000e-05
# Epoch 39/50
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 520s 632ms/step - accuracy: 0.8028 - loss: 0.5653 - val_accuracy: 0.8091 - val_loss: 0.5684 - learning_rate: 4.0000e-05
# Epoch 40/50
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 42s 53ms/step - accuracy: 0.7969 - loss: 0.6127 - val_accuracy: 0.8099 - val_loss: 0.5678 - learning_rate: 4.0000e-05
# Epoch 41/50
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 472s 604ms/step - accuracy: 0.8094 - loss: 0.5525 - val_accuracy: 0.8187 - val_loss: 0.5484 - learning_rate: 4.0000e-05
# Epoch 42/50
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 41s 53ms/step - accuracy: 0.8750 - loss: 0.4511 - val_accuracy: 0.8186 - val_loss: 0.5486 - learning_rate: 4.0000e-05
# Epoch 43/50
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 493s 631ms/step - accuracy: 0.8118 - loss: 0.5458 - val_accuracy: 0.8136 - val_loss: 0.5596 - learning_rate: 4.0000e-05
# Epoch 44/50
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 20s 25ms/step - accuracy: 0.7812 - loss: 0.4857 - val_accuracy: 0.8141 - val_loss: 0.5601 - learning_rate: 4.0000e-05
# Epoch 45/50
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 490s 628ms/step - accuracy: 0.8107 - loss: 0.5471 - val_accuracy: 0.8173 - val_loss: 0.5460 - learning_rate: 4.0000e-05
# Epoch 46/50
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 42s 53ms/step - accuracy: 0.7812 - loss: 0.7182 - val_accuracy: 0.8179 - val_loss: 0.5452 - learning_rate: 4.0000e-05
# Epoch 47/50
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 522s 629ms/step - accuracy: 0.8095 - loss: 0.5451 - val_accuracy: 0.8134 - val_loss: 0.5597 - learning_rate: 4.0000e-05
# Epoch 48/50
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 42s 53ms/step - accuracy: 0.8438 - loss: 0.5029 - val_accuracy: 0.8137 - val_loss: 0.5604 - learning_rate: 4.0000e-05
# Epoch 49/50
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 521s 631ms/step - accuracy: 0.8147 - loss: 0.5409 - val_accuracy: 0.8127 - val_loss: 0.5720 - learning_rate: 4.0000e-05
# Epoch 50/50
# 781/781 ━━━━━━━━━━━━━━━━━━━━ 42s 53ms/step - accuracy: 0.7969 - loss: 0.5024 - val_accuracy: 0.8121 - val_loss: 0.5729 - learning_rate: 4.0000e-05

# %%
# 6. Evaluate the model
print("\n6. Evaluating model performance...")
test_loss, test_acc = model.evaluate(X_test, y_test, verbose=0)
print(f"Test accuracy: {test_acc:.4f}")
print(f"Test loss: {test_loss:.4f}")
# Out:
# 6. Evaluating model performance...
# Test accuracy: 0.8179
# Test loss: 0.5452

# %%
# 7. Visualize training history
print("\n7. Visualizing training history...")
plt.figure(figsize=(12, 4))

# Plot training & validation accuracy
plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='lower right')

# Plot training & validation loss
plt.subplot(1, 2, 2)
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model Loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper right')

plt.tight_layout()
plt.show()
# Out:
# 7. Visualizing training history...

# %%
# 8. Make predictions on test data
print("\n8. Making predictions...")
y_pred = model.predict(X_test)
y_pred_classes = np.argmax(y_pred, axis=1)
y_true_classes = np.argmax(y_test, axis=1)
# Out:
# 8. Making predictions...
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 21s 66ms/step

# %%
# 9. Display confusion matrix
print("\n9. Generating confusion matrix...")
cm = confusion_matrix(y_true_classes, y_pred_classes)
plt.figure(figsize=(12, 10))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=class_names, yticklabels=class_names)
plt.xlabel('Predicted')
plt.ylabel('True')
plt.title('Confusion Matrix')
plt.show()
# Out:
# 9. Generating confusion matrix...

# %%
# 10. Display classification report
print("\n10. Classification Report:")
print(classification_report(y_true_classes, y_pred_classes, target_names=class_names))
# Out:
# 10. Classification Report:
#               precision    recall  f1-score   support
#
#     airplane       0.86      0.84      0.85      1000
#   automobile       0.91      0.93      0.92      1000
#         bird       0.83      0.70      0.76      1000
#          cat       0.77      0.58      0.67      1000
#         deer       0.78      0.80      0.79      1000
#          dog       0.87      0.64      0.73      1000
#         frog       0.64      0.97      0.77      1000
#        horse       0.90      0.84      0.87      1000
#         ship       0.89      0.93      0.91      1000
#        truck       0.84      0.94      0.88      1000
#
#     accuracy                           0.82     10000
#    macro avg       0.83      0.82      0.82     10000
# weighted avg       0.83      0.82      0.82     10000

# %%
# 11. Visualize some predictions
print("\n11. Visualizing predictions...")
def plot_image(i, predictions_array, true_label_array, img_array):
    true_label = np.argmax(true_label_array[i])
    predicted_label = np.argmax(predictions_array[i])

    plt.grid(False)
    plt.xticks([])
    plt.yticks([])

    plt.imshow(img_array[i])

    color = 'blue' if predicted_label == true_label else 'red'

    plt.title(f"Pred: {class_names[predicted_label]} ({predictions_array[i][predicted_label]:.2f})\n" +
              f"True: {class_names[true_label]}", color=color)

# Plot the first 25 test images with their predicted labels
plt.figure(figsize=(12, 12))
for i in range(25):
    plt.subplot(5, 5, i+1)
    plot_image(i, y_pred, y_test, X_test)
plt.tight_layout()
plt.show()
# Out:
# 11. Visualizing predictions...

# %%
# 12. Save the model
model.save('cifar10_cnn_model.h5')
print("\nModel saved as 'cifar10_cnn_model.h5'")

print("\nExperiment completed successfully!")
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Model saved as 'cifar10_cnn_model.h5'
#
# Experiment completed successfully!
